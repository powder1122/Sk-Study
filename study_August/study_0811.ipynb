# %% [markdown]
# # 8월 11일
# - 애플리케이션 보안 6일차
# - 미니 프로젝트

# %% [markdown]
# ## 정리
# ### 1일차
# - 하드닝
# - 이메일 서버 보안 인증 3가지
# - 어플라이언스 사례, '식' 구분단위 사용.
# - IT 정보보호 구축 가이드의 대표적인 솔루션 각각의 구분
# - 망분리, 블록체인, 제로 트러스트!
# - 파일 악성코드와 파일리스 악성코드
# - DNS의 재귀적 호출 구조!!!
# - HTTP/HTTPS
# - 클라우트에선 LB단에서 지원
# - 암호 알고리즘 - ShA~
# - 액티브엑스의 보안의 3종세트  --> 논액티브엑스로
# - 최근 보안 키워드
#
# ### 2일차
# - 취업/이직 팁 --> 채용공고 매일 보기
# - AI for Security!
# - 트랜잭션
# - 분산병렬
# - 서버리스
# - Vercel/Netlify (SaaS) --> 모의해킹 시 화면만 볼 수 있음. ChatGPT도 화면만 볼 수 있다. --> 블랙박스, 입출력만 볼 수 있어 난이도 높음
# - 상태/무상태 기반
# - 지식 전문성이 없으면 AI 활용도가 떨어진다! 판단하기 위해선 지식이 필요!
# - 쿠키 = JWT/JWS
# - ASM 기계화가 가능한 이유?
# - 설치에 따른 모바일 앱의 구분
#     - 모바일 웹 앱이 많은 비중을 차지하는 중
# - 망분리 완화
# - 인공지능을 활용해서 보안의 어떤 문제를 해소할 수 있을까
# - GPT에 대한 질문들, 활용 방법. 개인적인 튜닝이 필요
#
# ### 3~5일차
# - 컨테이너를 통해 프론트엔드와 백엔드 개념 정립
#     - DevSecOps: 프로덕트 시큐리티(Product), 인프라(제품) 보안에 가까운 개념. <-- 솔루션 개발, 솔루션 베이스인 사람들이 주로 하는 업무.
# - 분류와 회귀를 보안에서 어떻게 사용할지?
# - 인프라 공부하자!
#     - 책을 한 권씩 읽자!
#     - 데이터센터 보안 엔지니어: 블루 오션. 필요도 상승. 전 세계에 증가
# - NoSQL 빠르게 발전 중
# - 디지털화폐 관련 경력 채용이 증가.
# - 자신의 커리어를 높이기 위한 공부와 채용을 위한 공부를 병행해야 한다!
# - 출발이 늦은 사람들에게는 제너럴리스트 지향이 좋을 수 있다.
# - 현재는 공급망 보안이 중요한 키워드가 되었다.
# - 전자금융감독규정 해설서
#     - 변화가 많을 때 공부할 내용이 많아진다.
#     - 또 다른 기회가 되기도 함
#
#
# - 공부한 내용 및 가이드라인, 참고자료, 참고링크, 실습, 판서 --> 복기, 공부 필수!

# %% [markdown]
# # [프로젝트] LLM 애플리케이션 취약점 진단 및 보고서 작성
# - R&R 지정 : 발표자, PM, 자료조사, 기준작성, 진단, 결과보고서 작성
# - Step1. 엑셀표로 취약점 진단 기준을 매핑한다. → 진단항목(제출)
# - Step2. 진단대상을 선정하고, 취약점 진단을 수행한다. → 진단결과(제출)
# - Step3. 모든 결과 내용을 기반으로 발표자료를 구성한다. → 발표자료(제출)
#
#
# ## Step1. 생성형 AI(LLM) 보안 취약점 진단 기준 작성
# ### 참고자료
# 1. **생성형 AI 보안 가이드라인 : 확장**
# 2. **OWASP Top 10 : 웹 취약점 (일부) custom**
# 3. **OWASP Top 10(LLM Application) : LLM 취약점 (일부)**
# 4. **SK 쉴더스, LLM 취약점 진단 기준 : 통합, 에이전트, 모델 (일부)**
#
# ## Step2. 취약점 진단 대상(LLM) 선정
# 1. 웹 기반(SaaS) : ChatGPT(MS Azure), Cluade(AWS), Gemini(GCP), Grok, Deepseek, 에이닷(SK) 등 선택
# 2. Local(온프레미스) : Ollama 설치 -> DeepSeek-R1 모델 설치 / Local 세팅 : LM Studio 사용(lms)
#     - 1번만 하겠다
#     - 2번만 하겠다
#     - 1,2번 모두 하겠다
#
# ## Step3. 취약점 진단 대상(LLM)에 맞춰 진단 수행
# - 취약점 기준 | 대상1 | 대상2 | 대상3 | 진단 결과
# - 엑셀 시트(SK 쉴더스_1조_LLM 보안 취약점 진단 프로젝트.xlsx)에 기입
#
# ## Step4. 취약점 진단 기준 및 결과 요약
# - 기준, 결과, 주요 착안사항, 배운 점, 어려웠던 점
# - PPT 양식(SK 쉴더스_1조_LLM 보안 취약점 진단 프로젝트 발표.pptx)에 정리
