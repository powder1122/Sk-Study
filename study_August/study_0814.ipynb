# %% [markdown]
# # 8월 14일
# - 개인정보보호 2일차

# %% [markdown]
# ## 개인정보 처리 동의서 작성 시 점검사항
# - 온라인과 오프라인에서의 가입 및 탈퇴, 동의 여부가 다르다면 불법!
# - 자동 수집 장치에 의해 수집되는 개인정보여도 영리 추구를 위한 동의는 추가로 받아야 함
#     - 쿠키
#     - 다크패턴(눈속임) 주의 - 개보위 중점 착안사항(구글, 메타 천억원대 과징금)
#     - 동의 만능주의: 동의만 받으면 OK. 쌍방책임이 될 수 있음
#     - 쿠키 종류: 광고, 보안, 기능(Depth)의 선택(정보주체)
#         - 국내에서는 선택이 불가능 - 기술적 매커니즘(프론트엔트) 필요
#     - 개인정보 처리방침: 쿠키 평가(무슨 목적으로 수집하는지, 고지가 되었는지)
#     - 개인정보중에서 행태정보!
#
# ### 개인정보처리 동의 시 잘못된 사례
# - 동의 거부 시 불이익 고지가 미흡한 사례
# - 향후 이용 가능성을 고려해 민감정보를 수집한 잘못된 사례
#     - 잘 모르겠으면 사요할 때 수집해야 한다.
# - 마케팅 목적의 불분명한 안내
#     - 수집목적을 분명하게 안내해야함.
# - 동의 없는 홍보 및 마케팅 목적의 사용

# %% [markdown]
# ## 개인정보 수집 목적 범위내 제3자 제공
# - 정보주체의 동의를 받은 경우
#
# - 제3자 정보 제공
#     - 물리적, 전송, 접근권한 부여(방화벽을 열어주는 행위 포함) 등을 모두 포함한다.
#     - 제공의 범위를 넓게 볼 필요가 있다.
#
# - 법령 - 시행령 - 고시에 있는 항목은 합법. 이외에는 불법
#
# ### 개인정보 수집 목적 내 이용-제3자 제공
# - 정보주체와의 계약의 체결 및 이행을 위하여 불가피하게 수반되는 경우 제공 불가!
#
#
#
# ### 개인정보 수집 목적 외 이용-제3자 제공
# - 공공기관만 해당하는 법과 모든 기업에 해당하는 법이 있음
# - 명백히 정보주체 또는 제3자의 **생명,신체,재산**의 이익에 필요한 경우 예외적 허용!
#
# - 목적 외 이용의 잘못된 사례 보기(개인정보보호법 주요내용 page36)
#
# - 제공받은 제3자 정보에 대한 책임(R&R)은 제공받는 자에게 있다.
#     - 제공받는자가 데이터의 보안, 안전하게 처리 등의 작업을 해야 하고, 문제 발생 시 책임을 진다.
#
#
# ### 개인정보 수집 출처 등 고지
# - 게시와 고지는 다르다! 고지는 상대가 볼 때까지 보내는 것
# - '즉시'의 시간적 개념 해석
#     - 통상, 정보통신망법: 3일(72시간)
#     - 통상, 개보법: 5일(120시간)
#     - 특정 조항에서는 즉시를 10일(영업일 기준)이라고 해석
#     - 특정 조항에서는 즉시를 3일(72시간)이라고 해석
#     - 침해사고와 같은 급박한 상황의 즉시는 24시간으로 해석(특별한 사유)
#         - 초동조치, 확산방지, 대피, 구호
#
# - 처리 정지는 개인정보의 모든 것을 정지, 잊혀질 권리를 보장하라는 것으로 정보를 삭제하는 것이다!
#
# - 고지의무 대상 개인정보처리자
#     - 5만명 이상의 민감정보 또는 고유식별정보를 처리하는 자
#     - 100만명 이상의 정보주체에 대한 개인정보를 처리하는 자
# - 고지하였다는 사실, 알린 시기, 알린 방법을 개인정보 파기시까지 보관
#     - 홍길동이라는 사람의 데이터 수집, 정보 제공, 이용, 보관, 파기: 기록
#     - 수집 출처, 동의, 별도 기타 관련 기록: 같이 보관
#     - 홍길동 개인정보 파기: 모든 관련기록 소각(복구 불가능한 방법으로) 안티 포렌식
#     - 보통 일 단위로, 12시간 단위로 DB 배치
#     - 누락이 있거나 로그 아카이브, 백업, 소산 안 지운 경우: 파기 미흡

# %% [markdown]
# ## 개인정보 파기
# - '지체없이' 시간적 개념 해석
#     - 통상, 개보법 기준: 5일(120시간)
# - 디가우저, 모세 시큐리티 하드웨어 파쇄 등을 통해 파기
#     - 전자적 파일 형태는 덮어쓰기와 같이 복원 불가능한 방법으로 영구 삭제(3~18번 덮어쓰기 수행)

# %% [markdown]
# ## 민감정보, 고유식별정보 처리제한
# - 민감정보 및 고유식별정보는 원칙적으로 처리 금지
# - 위반 시 5년 이하의 징역 또는 5천만원 이하의 벌금
# - 주민등록번호는 동의로는 처리할 수 없다!
#
# ## 생체정보의 처리
# - 생체인식정보
#     - 얼굴 사진(영상)의 경우: 얼굴 사진(영상)에서 특징점 등을 기술적으로 추출 목적으로 출입통제 시스템 등에 사용하는 경우
#
#     - 음성의 경우: AI스피커에서 입력된 사람의 음성을 통해 특징점 등을 기술적으로 추출하여 말하는 사람이 누구인지 확인해 응답하는 경우
#
#     - 민감정보 O
#
# - 일반적인 생체정보
#     - 얼굴 사진(영상)의 경우: 얼굴 사진(영상)에서 특징점 등을 기술적으로 추출하지만 성별, 감정상태 등을 알아보기 위해 사용되는 경우
#
#     - 음성의 경우: AI스피커에서 입력된 사람의 음성을 통해 특징점을 기술적으로 추출하지만 단순히 화장의 감정상태를 알아보기 위해 사용하는 경우
#
#     - 민감정보 X
#
# - 개인정보보호법 위반 사유가 드러날 때
#     1. 보도자료: '너네 회사 해킹됐어요', '너네 회사 데이터 유출됐어요'
#         - 고객 신고
#         - 경찰서, 개보위
#     2. 개인정보보호 평가/실태 점검(온라인, 오프라인)
#         - 개인정보보호 모니터링 요원
#         - 미흡 --> 실태 점검 경고 고지
#         - 2차례 이상 고지했을 경우에도 조치가 없다면? 현장 점검 --> 통보
#         - 미흡, 불성실, 협조X 시 과태료&신고
#         - 실태 점검 결과 --> 외부 게시

# %% [markdown]
# ## 주민등록번호의 처리제한
# - 법률·대통령령·국회규칙·대법원규칙·헌법재판소규칙·중앙선거관리위원회규칙 및 감사원규칙에서 요구하거나 허용하지 않으면 처리가 불가능하다!
#
# - 인터넷으로 회원 가입 시 주민등록번호를 사용하지 않는 가입 방법을 제공하여야 함
#
# - 위반 시 3천만원 이하의 과태료

# %% [markdown]
# ## 이동형 영상정보처리기기의 설치 운영 제한
# - 업무를 목적으로 공개된 장소에서 이동형 영상정보처리기기로 촬영은 일반적으로 금지
# - 사람 또는 그 사람과 관련된 사물의 영상(개인영상정보)을 촬영 금지
# - 업무 목적: 개인정보처리자가 대상이 됨, 일반 개인의 사적인 촬영은 제외됨(법에서 제외)
# - (참고) 고정형 영상정보처리기기는 누구든지 공개된 장소에서 원칙적으로 설치운영 금지
#
# - 촬영이 허용되는 경우
#     - 제15조(개인정보의수집·이용) 제1항각호(제1호~제7호)의 어느 하나에 해당하는 경우
#     - 촬영 사실을 명확히 표시하여 정보주체가 촬영 사실을 알 수 있도록 하였음에도 불구하고 촬영 거부 의사를 밝히지 아니한경우.
#     - 이 경우 정보주체의 권리를 부당하게 침해할 우려가 없고 합리적인 범위를 초과하지 아니하는 경우로 한정
#
#
#
# - 촬영 사실을 명확히 표시하는 방법
#     - 불빛, 소리, 안내판, 서면, 안내방송또는이에준하는수단, 드론에 의한 항공촬영 등 촬영방법의 특성으로 인해 정보주체에게 촬영 사실을 쉽게 알 수 있도록 알리기 어려운 경우에는 홈페이지 공지 등 고시
#
# ## 업무위탁에 따른 개인정보 처리 제한
# - 개인정보 처리업무 위탁 문서화
#     - 문서에 포함되는 내용 확인 (Page 52)
# - 위탁하는 업무 내용, 수탁자를 인터넷 홈페이지 등에 공개
# - 홍보나 판매 권유 업무 위탁 시 업무 내용과 수탁자를 정보주체에게 통지
# - 수탁자가 개인정보를 안전하게 관리할 수 있도록 수탁자 교육, 감독
# - 수탁자는 위탁 받은 업무 범위를 초과한 개인정보 이용 및 제3자 제공 금지(위반 시 5년 이하의 징역 또는 5천만원 이하의 벌금)
#
# - 위탁자의 책임 확대: 수탁자 → 재수탁자
#     - 기존에는 위탁자가 모든 책임을 졌다.

# %% [markdown]
# ## 가명정보의 처리 특례
# - 원상태로 복원하기 위한 추가정보를 사용하지 아니하고는 특정 개인을 알아볼 수 없도록 가명처리한 정보
#
# - 정보주체의 동의 없이 가명정보의 처리
#     - 개인정보처리자는 통계작성, 과학적 연구, 공익적 기록보존 등을 위하여 정보주체의 동의 없이 가명정보를 처리할 수 있음
#     - “통계”란 특정 집단이나 대상 등에 관하여 작성하는 수량적인 정보를 통계 작성의 목적은 시장 조사와 같은 상업적 목적으로 가능함
#     - “과학적연구”란기술의개발과실증, 기초연구, 응용연구 및 민간 투자 연구 등 과학적 방법을 적용하는 연구
#     - “공익적기록보존”이란, 공공의 이익을 위하여 지속적으로 열람할 가치가 있는 기록을 보존하는 것 -- 공익이 공공기관을 의미하는 것이 아니다!
#
# -  가명정보의 제3자 제공 시 특정 개인을 알아볼 수 있는 정보의 미포함
#     - 배경 블러처리, 도로명 데이터 삭제 등의 작업이 필요. 추가데이터로 개인이 식별 가능하여 일어난 일에 대해서는 처리자가 책임을 진다.
#     - 가명정보가 재식별 되지 않는지에 대한 책임은 기본적으로 가명정보를 제공받는 제3자에게 있음
#
# - 가명정보의 처리 단계
#     1. 목적 설정 등 사전 준비
#     2. 위험성 검토
#     3. 가명처리
#     4. 적정성 검토
#     5. 안전한 관리
#
# - 가명정보 지원 플랫폼
#
# - Q. 우리나라에는 가명정보, 결합, 키관리, 연계 전문가가 많을까?
#     - 개인정보보호 전문가 중에서 아직 블루 오션
#     - 수요도 적고 아직은 활성화 되지 않았음
#     - 그런데, 최근 망분리 완화, N2SF/제로 트러스트 준비 --> 공통: 가명처리(폭발적 증가 예상)
#     - 기업의 고민은 '가명처리 골치아픈데, 대체 누가 해야 할까?'

# %% [markdown]
# ## 개인정보의 국외 이전
# ### 국외이전 요건 강화
# 1. 정보주체의 별도 동의
# 2. 정보주체와의 계약의 체결 및 이행을 위하여 필요한 경우로서
#     - 개인정보처리방침에 공개하거나
#     - 개별 통지한 경우에만 가능
# 3. [신설]법률, 조약, 국제협정에 개인정보 이전에 관한 내용이 있는 경우
# 4. [신설] 개인정보를 이전받는 자가 ISMS-P 인증을 받고(1) 개인정보안전조치(2) 정보주체 권리보장에 필요한 조치를 수행하는 경우
# 5. [신설] 개인정보가 이전되는 국가 또는 국제기구의 개인정보보호 수준이 우리나라와 동등 수준을 갖췄다고 개인정보위가 인정하는 경우
# - 알리와 같이 중국 기업으로의 국외 이전이 많다.
#
# ### 국외이전 중지
# - 중지 요건
# 1. 국외 이전 가능 요건 위반
#     - 국외이전 가능 5가지 가능 요건 중 하나 이상 위반한 경우
# 2. 국외 이전 시 준수사항 위반
#     - 제17조, 제18조, 제19조, 제5장 정보주체의 권리 보장
# 3. 개인정보보호법을 위반하는 개인정보 국외 이전 계약 체결 금지 위반
# 4. . 이전받는 자(기업등)나 국가, 국제기구가 개인정보보호 수준이 적정하지 않아 정보주체에 피해가 발생하거나 발생할 우려가 현저한 경우
#
# ### CBPR
# - https://cbpr.kisa.or.kr/

# %% [markdown]
# ## 요약
# ### 개인정보의 정책/관리현황 공개 방식
# - 내부: 내부관리계획    |  내부 임직원, 임직원 선언, 개인정보보호 선언문
# - 외부: 개인정보처리방침 | 외부 고객, 고객과의 약속, 고객 이 회사의 신뢰도 판단
# - 내부 외부 모두 100% 동일해야 함! (일관성, 표준화, 현행화)
#     - 내*외부 개정/공표/교육/수행/문서화 필요
#
# - 전송요구권 증가에 따른 정보보호적인 나비효과
#     - 마이데이터 API 호출(전송 송수신) 증가 | API 보안 필요
#     - 인공지능의 학습, 개인 최적화         | AI 보안 필요
#     - 네트워크적인 통신                   | 연합학습, 온디바이스컴퓨팅
#     - 분산 병렬처리(파편화)               | 개인정보의 처리 모니터링, 중앙집중적인 제어
#     - 데이터 민감도, 중요도(차등화)        |  고위험, 고영향, 민감한 데이터 분류(라벨링) 보안
#     -
#
# ### 정보주체의 권리 보장
# - 열람 요구권: 10일 이내 열람 or 거부(사유 소명)                | Read
# - 정정,삭제, 처리 정지, 동의 철회(기록만 남기고 삭제): 10일 이내   | Delete(Write)
#
#
# - 결정 거부권
# - 설명 요구권
#
# - 개인정보처리자 의무사항
#     1. 결정 거부, 설명 요구에 대한 개인정보처리자의 조치
#     2. 자동화된 결정의 기준과 절차, 개인정보가 처리되는 방식 등을 정보주체가 쉽게 확인할 수 있도록 공개
#         - 사람인지 AI인지 확인할 수 있도록 명시

# %% [markdown]
# # 2교시
# - 숫자 나오는 것들은 암기가 필요함(중요도 높음)
#
# ## 토론(Security for AI)
# - [리스크 관리]
#
# - 생성형AI 활용, 개발 → 벤더, 개발자, 개인, 오픈소스
#
# - AI 활용, 개발 → 공개된 데이터 활용하는 자
#
# - AI 서비스 제공(피해방지 조치) → 정보주체 피해(방지, 구제, 완화)
#
#
#
# - [토론 시 착안사항]
#
# - (1) 개발 시 주의사항
#
# - (2) 인공지능 개발 시, 데이터를 어떻게 통제하라는 것인지?
#
# - (3) 내가 개발자로써, 인공지능 앱을 개발한다면 어떤 개인정보보호적인 기능을 구현하면 좋을지?
#
# - (4) 오픈AI, 앤스로픽, 퍼플렉시티, X, 스캐터랩스(AI윤리) → 회사들의 개인정보처리방침, 서비스 이용 규칙
#
# - Q. 정당한 이익이란?
#     - 개인정보 처리자의 관점
#
# - Q. PbD란?
#     - Privacy by Design 7대 기본원칙(IPC, Ann, Cavoukian). 개인정보 보호 가이드라인 P.15
#
# - Q. 어뷰징
#     - 디지털 환경에서 불법 프로그램 운영, 타인 계정 도용, 다중 계정 접속 등의 방법으로 부당한 이익을 취하는 행위
#     - 개인정보를 남용/악용하는 것.
#     - 재발 방지 대책이 중요
#
# - Q. 판별 AI는 뭘까
#     -  AI 프라이버시 리스크 관리 모델 P.13
#
# - Q. 합성 데이터?
#     - AI 프라이버시 리스크 관리 모델 P.41
#
# - Q. RLHF를 활용한 미세조정?
#     - AI 프라이버시 리스크 관리 모델 P.42
#     - AI 모델이 생성한 출력물에 사람이 점수 또는 순위(라벨)을 부여하고, 이를 토대로 보상모델을 훈련하는 것.
#
# ### 페이지 요약
# - 추진 배경 p.5
#     - 인공지능 시스템에 의한 결정은 사람에 의한 결정에 비해 그 확장성으로 인해 사회적 파급력이 매우 크다.
#     - 완전히 자동화된 인공지능(AI) 시스템만으로 정보주체의 일상생활 속에서의 권리 또는 의무에 큰 영향을 미치고 있다.
#     -  인공지능(AI) 기술을 이용한 자동화된 결정 과정의 투명성을 높임으로써 개인정보보호법의 목적인 개인의 자유와 권리 보호 및 개인의 존엄과 가치를 구현하기 위함.
#
# - 자동화된 결정에 대한 정보주체의 권리 도입 목적: 투명성 + 정보 제공 등
# 대응권 보장 p.7
#
# - p.15~16
# - 개인정보처리자의 조치사항(정보주체는 자동화된 결정에 대해 거부권, 설명 등 요구권을 가진다)
#     1. 거부할 수 있는 권리 p.17
#         - 요건: 자동화된 결정이 정보주체의 권리 또는 의무에 중대한 영향을 미치는 경우에 행사할 수 있음 p.6
#         - '중대한 영향' 판단 기준: 생명, 신체의 안전과 관련이 있는지, 권리 박탈이나 지속적인 제한이 발생하는지, 통상적으로 받아들일 수 있는 한도를 넘어서는 의무가 발생하는지 등을 종합적으로 고려 p.18
#         - 제한되는 경우: 자동화된 결정이 정보주체의 동의, 법률, 또는 계약에 근거해 이루어진 경우에는 거부권이 제한 p.20
#         - 개인정보처리자의 조치: 거부 요구를 받으면 정당한 사유가 없는 한 다음 중 하나를 조치하고 결과를 알려야 합니다
#     2. 설명 등 요구권
#         - 설명 요구: 자동화된 결정이 있을 경우, 정보주체는 결정의 기준 및 처리 과정에 대한 설명을 요구할 수 있음 p.25
#         - 개인정보처리자의 조치: 정당한 사유가 없는 한, 결정의 결과, 사용된 주요 개인정보의 유형, 결정에 미친 영향, 처리 과정 등을 포함한 간결하고 의미 있는 설명을 제공해야 합니다. 단, 중대한 영향을 미치지 않는 결정의 경우 공개된 사항을 활용하여 설명할 수 있습니다. p.25
#         - 검토 요구: 정보주체는 개인정보 추가 등의 의견을 제출하여 의견이 자동화된 결정에 반영될 수 있는지 검토를 요구할 수 있습니다 p.25
#         - 개인정보처리자의 조치: 정당한 사유가 없는 한, 제출된 의견의 반영 여부를 검토하고 그 결과를 알려야 합니다. p.25
#
# - 개인정보처리자의 조치
# - 거절의 정당한 사유 p.31
#     - 개인정보처리자는 정보주체의 요구에 대해
#         - 정당한 사유가 있는 경우 거절할 수 있습니다. 정당한 사유는 정보주체가 입을 불이익과 개인정보처리자 또는 제3자의 이익을 비교해 개별적으로 판단합니다
#         - 거부권 거절 사유: 다른 사람의 생명·신체·재산 등 이익을 침해할 우려가 있거나 , 개인정보처리자의 재산 등 이익을 부당하게 침해할 우려가 있는 경우 , 또는 계약 이행이 곤란해지는 경우 등이 있습니다.
#         - 설명요구 거절 사유: 법률에 의해 설명이 금지되거나 제한되는 경우 , 영업비밀 등 개인정보처리자나 제3자의 이익을 침해할 우려가 있는 경우 등이 해당합니다.
#         - 검토요구 거절 사유: 제출된 의견이 이미 반영되었거나 동일한 내용이 반복적으로 제기된 경우.
#     - 처리기간 및 고지 방법 p.36
#         - 요구에 따른 조치: 요구를 받은 날로부터 30일 이내에 서면 등의 방법으로 알려야 합니다. 30일 이내 처리가 어려운 정당한 사유가 있는 경우 2회에 한하여 각 30일까지 연장할 수 있습니다.
#         - 요구 거절: 거절하는 경우에는 그 사유와 이의제기 방법 및 절차를 요구를 받은 날로부터 10일 이내에 알려야 합니다
#
# - 사전 공개 의무 p.38
# - 개인정보처리자는 자동화된 결정의 기준과 절차, 처리 방식 등을 정보주체가 쉽게 확인할 수 있도록 인터넷 홈페이지 등을 통해 공개해야 합니다.

# %% [markdown]
# ## 개인정보의 안전한 관리
# - 개인정보처리자: "개인정보처리자"란 업무를 목적으로 개인정보파일을 운용하기 위하여 스스로 또는 다른 사람을 통하여 개인정보를 처리하는 공공기관, 법인, 단체 및 개인 등을 말함
# - 개인정보책임자: 개인정보처리에 관한 업무를 총괄해서 책임지거나 업무처리를 최종적으로 결정하는 자
# - 개인정보취급자: 개인정보처리자의 지휘·감독을 받아 개인정보를 처리하는 임직원, 파견근로자, 시간제 근로자 등
# - 개인정보처리시스템: 데이터베이스와 같이 체계적으로 구성한 시스템. 노트 패드에 막 적은 것은 포함되지 않는다.
#
#
# ## 안전조치의무(제29조)
# - 개인정보가 분실·도난·유출·위조·변조 ·훼손되지 않도록 안전성 확보 조치를 해야 함
# 1. 개인정보의 안전한 처리를 위한 내부 관리계획의 수립·시행·점검
# 2. 개인정보에 대한 접근 권한을 제한하기 위한 조치
# 3. 개인정보에 대한 접근을 통제하기 위한 조치
# 4. 개인정보를 안전하게 저장ㆍ전송하는데 필요한 조치
# 5. 개인정보 침해사고 발생에 대응하기 위한 접속기록의 보관 및 위조ㆍ변조 방지를 위한 조치
# 6. 개인정보처리시스템 및 개인정보취급자가 개인정보 처리에 이용하는 정보기기에 대해 컴퓨터바이러스, 스파이웨어, 랜섬웨어 등 악성프로그램의 침투 여부를 항시 점검ㆍ치료할 수 있도록 하는 등의 기능이 포함된 프로그램의 설치ㆍ운영과 주기적 갱신ㆍ점검 조치
# 7. 개인정보의 안전한 보관을 위한 보관시설의 마련 또는 잠금장치의 설치 등 물리적 조치
#
#
# ### 안전성 확보조치를 취할 의무 위반의 판단(판례)
# - 대법원 판사가 읽고 판단.
# - 해킹 등 침해사고 당시 일반적으로 알려져 있는 정보보안 기술 수준
# - 정보통신서비스 제공자의 업종과 영업 규모 - 예: 예스24, 총 매출액 등
# - 정보통신서비스 제공자가 취하고 있던 전체적인 보안조치의 내용 - 잘 했었는가
# - 정보보안조치에 필요한 경제적 비용 및 그 효용의 정도
# - 해킹기술 수준과 정보보안기술 발전 정도에 따른 피해 발생 회피 가능성
# - 정보통신서비스제공자가 수집한 개인정보의 내용과 개인정보 누출로 인하여 이용자가 입게 되는 피해 정도 등
#
# - 현재 법의 수준에 크게 어긋나지 않는 보안 수준을 유지하면 큰 책임을 물기 어렵다!
#     - 그러면 딱 법을 준수할 만큼만 보안을 하면 되는 거 아닌가?
#         - 직원: 제로 트러스트와 N2SF를 해야 합니다!
#         - 사장: 법에서 하라고 했어? 아니면 안해!
#         - **보안을 제약하는 요건이 되버리고 있음**
#         - 자율적으로 보안을 하도록 권장하고 있음(권장) --> 자율 보안 체계 감사(환경 조성 목적)
#
# - 개인정보의 안전성 확보조치 기준과 기술적 관리적 보호조치 기준 통합!

# %% [markdown]
# ## 안전조치의무 주요 조치사항 및 방법
# ### 접근 권한 관리
# - 최소 범위로 권한 차등부여 및 변경-말소!
#     - 실제로는 잘 지키지 않는다.
# - 접근권한 부여, 변경, 말소 내역 3년 이상 보관
# - 1인 1계정 발급 및 공유 금지
#     - 내 PC에서만 로그인 가능!(또는 중복 로그인 차단)
#     - MAC 주소 지정 등의 방법
#     - 유닉스/리눅스 root 계정의 경우 하나만 생기기 때문에 1인 1계정이 어렵다. --> 공유 관리 대장 작성(정당한 사유)
# - 인증수단 안전하게 관리
# - 권한 도용 방지
#     - 일정 횟수 이상 인증 실패 시 접근 제한, 잠금을 풀려면 직접 가서 여러 인증 절차를 거쳐야 함.
#
# - 인증 수단
#     - SSO, AD
#     - SNS(O-Auth, OIDC) 로그인
#     - 투펙터 vs 투채널: 멀티 팩터
#     - FIDO, OTP: 보안 위험 급증
#     - 브라우저, 블록체인, 생체인증, 간편인증: 인증이 간편하고 쉬워질수록 보안은 약해진다!
#         - 간편인증: 취약점이 너무 많아 보안을 추가(전자서명 등)하는 인터페이스가 필요하다는 의견(KISA)
#         - 간편인증 서비스에 대한 인터페이스도 하나의 프로젝트가 될 수 있다!
#     - 금융권: 비대면 인증
#
#
# ### 접근 통제
# - 불법적인 접근 및 침해사고 방지를 위한 안전조치
#     - DHCP + 동적 IP
#
# - 외부 접근 통제
#     - 원천적인 외부 접근 차단
#         - 망 연계를 통해 들어오는 연결을 어떻게 필터링할 것인지
#
# - 노출 및 공유 설정 제한
#     - 인터넷 홈페이지, P2P 등을 통해 권한 없는 자에게 공개 또는 유출되지 않도록 조치
#
# - 세션 타임 아웃
#     - 일정시간 이상 업무처리를 하지 않는 경우에는 자동 접속 차단 등 필요한 조치
#
# - 모바일 기기 관리
#     - 업무용 모바일 기기의 분실·도난 등으로 개인정보가 유출 되지 않도록 해당 모바일 기기에 비밀번호 설정 등의 보호조치
#
# - 망 분리
#     - 적용대상: 전년도 말 기준 직전 3개월간 그 개인정보가 저장-관리되고 있는 이용자 수가 일일평균 100만명 이상인 개인정보처리자(페이지 뷰를 기준. 한 명이 페이지 50개를 보면 50명)
#     - 관리자페이지.
#     - 파기: 개인정보처리시스템에 저장된 개인정보파일, 레코드, 테이블 또는 데이터베이스(DB)를 삭제하는 것을 의미
#     - 논리적/물리적 망 분리 모두 가능
#
#     - 망분리가 가장 잘 표현된 가이드라인:
#         - 전자금융감독규정 해설서(2025.08) 개정: 망분리(해킹 침해사고 대응)
#         - 물리적, 논리적, 망분리, 망연계, 본지점 망분리, 영업망 망분리, 연구개발망 분리 개념 이해

# %% [markdown]
# ## 개인정보파일의 등록 및 공개(제32조) : 공공기관만 해당
# - 개인정보 포털에서 공공기관에서 취급하는 개인정보 파일 확인 가능
#
# ## 개인정보 보호 인증(제32조의2)
# - 영향평가 전문인력
# - 자격있는 회사에 입사 후 자격증을 얻으면 공공기관을 대상으로 영향평가를 할 수 있다.
#
# ## 개인정보 유출 통지 등(제34조) --> 통지
# - 정의: 개인정보 유출 등: 개인정보가 분실·도난·유출
# - 통지 요견: (1명 이상의 정보주체의) 개인정보가 유출 등이 되었음을 알게 되었을 때
# - 정당한 사유가 없는 한 지체없이(72시간 이내)
#     - 예외: 유출 등이 된 개인정보 의 확산 및 추가 유출등을 방지하기 위하여 접속경로의 차단, 취약점 점검·보완, 유출 등이 된 개인정보의 회수·삭제 등 긴급한 조치가 필요한 경우에는 그 조치를 한 후 지체 없이 정보주체에게 통지 가능
# ## ## 개인정보 유출 통지 등(제34조) --> 신고
# - 정의: 개인정보 유출 등: 개인정보가 분실·도난·유출
# - 신고 요건: 개인정보 유출 등이 되었음을 알게 되었을 때 다음 중 하나에 해당하는 경우
#     1. 1천 명 이상의 정보주체에 관한 개인정보가 유출 등이 된 경우
#     2. 민감정보, 고유식별정보가 유출 등이 된 경우
#     3. 외부로부터의 불법적인 접근에 의해 개인정보가 유출 등이 된 경우 //해킹에 의한 개인정보 유출
#     예외: 신고하지 않을 수 있는 요건
#         - 개인정보 유출 등의 경로가 확인되어 해당 개인정보를 회수·삭제하는 등의 조치를 통해 정보주체의 권익 침해 가능성이 현저히 낮은 경우
# - 정당한 사유가 없는 한 지체없이(72시간 이내), 예외 규정 없음

# %% [markdown]
# ## 개인정보 유/노출 예방 교육
# ### 개인정보 유출과 노출의 차이
#     - 모르는 사람들에게 정보가 넘어간다 --> 유출
#     - 회수가 가능한 그룹웨어 등이 보여진다(인터넷 중요 정보 게시 등) --> 노출
#
# - 퇴사자 계정이 살아있어 내부자 유출이 되는 경우도 존재
# - 엑셀파일 노출 사례
#
#
# - 관리자페이지 접근제어 미흡
#     - 특권계층은 특별 관리가 필요하다.
#     - 특권 계정은 더 타이트한 신뢰도를 가져야 한다. 강화된 보안 전략 필요!
#         - 더 많은 인증, 더 많은 권한, 짧은 세션 기간 등
#
# - 디렉터리 리스팅 보안설정 미흡 - 디렉터리 리스팅 취약점으로 인해 노출

# %% [markdown]
# # 개인정보보호 관련 직업
# - Q. 개인정보보호 관련해서 직업을 갖고자 한다면?
#     - 판례, 시나리오, 사례: 많이 학습
#     - IT 분야에서 법을 가장 잘 아는 사람
#     - 베이스가 IT여야 한다!
#
# - IT 기술적인 분야 --> 법, 규제, 인증, 표준 공부 --> 이직/전직 OK!
