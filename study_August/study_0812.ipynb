# %% [markdown]
# # 8월 12일
# - 애플리케이션 보안 7일차
# - 프로젝트 발표 - 피드백
#
# - **사실(증적)과 의견(가능성)을 구분해서 제시하면 좋겠다.** - 할루시네이션 주의. 고객을 현혹할 수 있다.
# - 말하지 않을 내용은 PPT에 담지 않는다. - 기본적인 것!
# - 엑셀은 Detail 설명용으로, PPT는 Presentation 요약용으로 사용한다. - PPT = 포트폴리오
#     - 주제, 팀소개, 역할, 문제점, 가설, 검증, 분석결과, **느낀점(킬포!)**
# - 시간 부족으로 인해 하지 못했던 부분을 모듈 프로젝트에서 보완하자!
# - 실제로 말을 하는 연습을 많이 하자! - 합격의 당락은 서류가 아닌 면접이다!
# - 실제로 동작 가능한 도구나 대시보드, 화면설계 등을 추가하면 좋을 것 같다.(선택)
# - 다른 조의 결과물을 통해 보완할 수 있어야 한다! - 개인의 역량. 하면 도움이 된다.
# - 많은 전문용어들이 쏟아지고, 이해 못하는 내용이 많을 것이다! --> 시간 내서 소화. 이 과정이 진정한 공부가 된다!
# - 생성형을 써보고, 보안에 적용하고, 스스로 달성한 결과를 설명한 경험은 금같이 귀하다! - 귀중한 경험을 공유하고 발표하면 보석이 된다.
# - 보안이라는 허들 안에서 하고 싶은 걸 모듈 프로젝트에서 하자!
# - 한 개를 진단하기는 쉽지만, 여러 개를 자동화 진단하긴 어렵다. - 시도해보자!
# - 포트폴리오로 잘 옮겨서 활용해라. 정리하지 않으면 쓰레기
# - 실제로는 외부에서의 해커 침입 뿐만 아니라, 내부 개발자/외주 개발자/API 제공 벤더/내부 LLM 사용자/보안 담당자/인프라 엔지니어/데이터 접근 가능자/개인정보처리, 취급자 등에 의해 보안 사고가 발생할 수 있음을 명심하자!
#
# - 남은 시간은 LLM 보안 위협의 대응 방안으로써 'AI GuardRails'의 실제 사례를 살펴보고, 어떻게 적용할 수 있을지, 실제 사례의 한계가 있을지 생각해보기.(영어 알아서 해독)
