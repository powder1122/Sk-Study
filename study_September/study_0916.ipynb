# %% [markdown]
# # 생성형AI를 활용한 AI 보안관제 및 통합로그
# - 6일차
# - 미니 프로젝트
# - 생성형 AI를 연계한 보안관제 도구(지원)를 구상하고 강사에게 검토를 받자
#     - 검토안에 포함되어야 할 내용
#     1. 도구 이름
#     2. 도구 용도
#     3. 도구 주요기능
#     4. 기대되는 입력
#     5. 기대되는 출력
#
#     - 검토: **유용성**, 구현가능범위(오후동안 구현 가능한 범위인지? 샘플 데이터 확보 가능한지?), 조 안에서의 역할과 책임
#
# - 0916_mini_proj 폴더에 정리
